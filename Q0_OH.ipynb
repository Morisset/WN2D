# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %load_ext autoreload
# %aimport WN2D_helper
# %autoreload 1

from WN2D_helper import make_grid, model_grid, l_dict
# Out:
# warng pyCloudy config: pyCloudy works better with matplotlib Triangulation

# %%
name='M5_2My_'

# %%
M3D = model_grid(name, dims=100, cut=None, limit=0.05)

# %%
print('12 + log(O/H) ' + ' '.join(f'{12 + v:7.2f}' for v in M3D.I1["OHs"]))
print('log(U)        ' + ' '.join(f'{v:7.2f}' for v in M3D.I1["logUs"]))
print('log(Q0)       ' + ' '.join(f'{v:7.2f}' for v in M3D.I1["logQ0s"]))
print('log(Rin)      ' + ' '.join(f'{v:7.2f}' for v in M3D.I1["logRins"]))
# Out:
# 12 + log(O/H)    6.87    6.99    7.12    7.24    7.37    7.49    7.62    7.74    7.87    7.99    8.12    8.25    8.39    8.53    8.67    8.81    8.94
# log(U)          -1.63   -1.74   -1.86   -1.97   -2.09   -2.21   -2.33   -2.45   -2.56   -2.68   -2.80   -2.91   -3.02   -3.12   -3.23   -3.34   -3.44
# log(Q0)         52.17   51.80   51.42   51.05   50.67   50.30   49.92   49.55   49.17   48.80   48.42   48.05   47.67   47.30   46.92   46.55   46.17
# log(Rin)        20.19   20.06   19.94   19.81   19.69   19.56   19.44   19.31   19.19   19.06   18.94   18.81   18.69   18.56   18.44   18.31   18.19

# %%
M3D.plot_params()
